# %% [markdown]
# # EOF Photo Compression
# #### Adapted from fingerprint notebook

# %%
#import Image
import urllib
#from StringIO import StringIO
import xarray as xr 
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
#from eofs.standard import Eof
#import imageio

# %%
filename = 'tiger.jpg'

# %%
plt.imshow(pic.get_data(100))
print(np.shape(pic.get_data(100)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8b3864a4e459> in <module>()
# ----> 1 plt.imshow(pic.get_data(100))
#       2 print(np.shape(pic.get_data(100)))
#
# NameError: name 'pic' is not defined

# %% [markdown]
# ### Turns out I can't get any of the packages to work and my environment won't update.....I don't think we ever resolved that problem at the begining of the semester during your office hours? Here's the image I was GOING to play with.

# %% [markdown]
# ![tiger.jpg](attachment:tiger.jpg)

# %% [markdown]
# ### Was thinking I would catch a signal with:
# ### - Stripes
# ### - Black top half/ lighter bottom half of photo
# ### - Some sort of signal for the tiger's body

# %% [markdown]
# ### I think the first things to go with reduction of data would be the details of the grass/twigs and the individual strands of fur. The whiskers too
